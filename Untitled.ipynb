# %%
import json

from Eval import eval_answer

# %%
data_experiment=eval_answer()
data_60_examples=eval_answer(flag=True)
# Out:
# questions_records[k] dict_keys(['original', 'v2'])
# ##############################
# data_name experiment
# selected_model {'agent': 'hf', 'model': 'Qwen/Qwen2.5-7B-Instruct:together'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'hf', 'model': 'meta-llama/Llama-4-Scout-17B-16E-Instruct:groq'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'hf', 'model': 'meta-llama/Llama-3.3-70B-Instruct:groq'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'hf', 'model': 'deepseek-ai/DeepSeek-V3.2-Exp:novita'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'hf', 'model': 'deepseek-ai/DeepSeek-V3.2:novita'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'hf', 'model': 'Qwen/Qwen3-235B-A22B-Instruct-2507:novita'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gwdg', 'model': 'qwen3-32b'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gwdg', 'model': 'qwen3-30b-a3b-thinking-2507'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gwdg', 'model': 'qwen3-coder-30b-a3b-instruct'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gwdg', 'model': 'mistral-large-instruct'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gwdg', 'model': 'deepseek-r1'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gwdg', 'model': 'deepseek-r1-distill-llama-70b'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# questions_records[k] dict_keys(['original', 'v2'])
# ##############################
# data_name 60
# selected_model {'agent': 'hf', 'model': 'meta-llama/Llama-4-Scout-17B-16E-Instruct:groq'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'hf', 'model': 'deepseek-ai/DeepSeek-V3.2-Exp:novita'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'hf', 'model': 'deepseek-ai/DeepSeek-V3.2:novita'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'hf', 'model': 'Qwen/Qwen3-235B-A22B-Instruct-2507:novita'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gwdg', 'model': 'qwen3-32b'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gwdg', 'model': 'qwen3-30b-a3b-thinking-2507'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gwdg', 'model': 'qwen3-coder-30b-a3b-instruct'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gwdg', 'model': 'mistral-large-instruct'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gwdg', 'model': 'deepseek-r1'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'hf', 'model': 'deepseek-ai/DeepSeek-V3.2-Exp:novita'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'hf', 'model': 'deepseek-ai/DeepSeek-V3.2:novita'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True

# %%
import pandas as pd
Data_experiment = pd.DataFrame(data_experiment)
Data_experiment.head()
# Out:
#    correctness  duration  type_ Crossed_edges no_of_edges no_of_nodes  \
# 0            1  1.124367     DI            no           3           4
# 1            0  0.881759  mixed            no           3           4
# 2            0  1.291369   inDI            no           3           4
# 3            0  0.894541     DI          True           3           4
# 4            0  1.762372  mixed          True           3           4
#
#                                model
# 0  Qwen/Qwen2.5-7B-Instruct:together
# 1  Qwen/Qwen2.5-7B-Instruct:together
# 2  Qwen/Qwen2.5-7B-Instruct:together
# 3  Qwen/Qwen2.5-7B-Instruct:together
# 4  Qwen/Qwen2.5-7B-Instruct:together

# %%
overall = Data_experiment.groupby('model')['correctness'].mean().reset_index()   
overall.head(100)
# Out:
#                                              model  correctness
# 0                Qwen/Qwen2.5-7B-Instruct:together     0.055556
# 1        Qwen/Qwen3-235B-A22B-Instruct-2507:novita     0.111111
# 2             deepseek-ai/DeepSeek-V3.2-Exp:novita     0.166667
# 3                 deepseek-ai/DeepSeek-V3.2:novita     0.111111
# 4                                      deepseek-r1     0.055556
# 5                    deepseek-r1-distill-llama-70b     0.000000
# 6           meta-llama/Llama-3.3-70B-Instruct:groq     0.000000
# 7   meta-llama/Llama-4-Scout-17B-16E-Instruct:groq     0.111111
# 8                           mistral-large-instruct     0.000000
# 9                      qwen3-30b-a3b-thinking-2507     0.000000
# 10                                       qwen3-32b     0.055556
# 11                    qwen3-coder-30b-a3b-instruct     0.000000

# %%
overall = Data_experiment.groupby(['model','type_'])['correctness'].mean().reset_index()   
overall.head()
# Out:
#                                        model  type_  correctness
# 0          Qwen/Qwen2.5-7B-Instruct:together     DI     0.166667
# 1          Qwen/Qwen2.5-7B-Instruct:together   inDI     0.000000
# 2          Qwen/Qwen2.5-7B-Instruct:together  mixed     0.000000
# 3  Qwen/Qwen3-235B-A22B-Instruct-2507:novita     DI     0.333333
# 4  Qwen/Qwen3-235B-A22B-Instruct-2507:novita   inDI     0.000000

# %%
overall = Data_experiment.groupby(['model','Crossed_edges'])['correctness'].mean().reset_index()   
overall.head()

import plotly.express as px
template='ggplot2'
df = overall
fig = px.bar(df, x="model", y="correctness",
             color='Crossed_edges', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/duration_di_indi.png")

# %%
import pandas as pd
Data_60 = pd.DataFrame(data_60_examples)
Data_60.head()
# Out:
#    correctness  duration type_ Crossed_edges no_of_edges no_of_nodes  \
# 0            0  0.673245                True           3           3
# 1            0  0.492084                True           3           3
# 2            0  0.441763                True           4           3
# 3            0  0.444273                True           4           3
# 4            0  0.592553                True           5           3
#
#                                             model
# 0  meta-llama/Llama-4-Scout-17B-16E-Instruct:groq
# 1  meta-llama/Llama-4-Scout-17B-16E-Instruct:groq
# 2  meta-llama/Llama-4-Scout-17B-16E-Instruct:groq
# 3  meta-llama/Llama-4-Scout-17B-16E-Instruct:groq
# 4  meta-llama/Llama-4-Scout-17B-16E-Instruct:groq

# %%
overall = Data_60.groupby(['model','no_of_edges'])['correctness'].mean().reset_index()   
overall.head()

import plotly.express as px
template='ggplot2'
df = overall
fig = px.bar(df, x="model", y="correctness",
             color='no_of_edges', barmode='group',template=template,text_auto=True,
             height=500)
fig.show()
fig.write_image("images/duration_di_indi.png")

# %%
overall = Data_60.groupby(['model','no_of_nodes'])['correctness'].mean().reset_index()   
overall.head()

import plotly.express as px
template='ggplot2'
df = overall
fig = px.bar(df, x="model", y="correctness",
             color='no_of_nodes', barmode='group',template=template,text_auto=True,
             height=500)
fig.show()
fig.write_image("images/duration_di_indi.png")
