# %%
import json

from Eval import eval_answer
# Out:
# Did not find file example.env.
# This is used to double check the key settings for the notebook.
# This is just a check and is not required.

# %%
direct_indirect_all,Crossed_not_crossed_all,no_of_edges_acc_all,no_of_nodes_acc_all=eval_answer()
direct_indirect_all_s2,Crossed_not_crossed_all_s2,no_of_edges_acc_all_s2,no_of_nodes_acc_all_s2=eval_answer(flag=True)
# Out:
# questions_records[k] dict_keys(['original', 'v2'])
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1-mini'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 2
# nc 16
# total_minutes 0.31666666666666665
# +++
# direct_indirect {'DI': {'c': 1, 'nc': 5, 'duration': 1.149911}, 'mixed': {'c': 1, 'nc': 5, 'duration': 1.274292}, 'inDI': {'c': 0, 'nc': 6, 'duration': 1.28686}}
# Crossed_not_crossed {'no': {'c': 1, 'nc': 8, 'duration': 13.181106}, 'True': {'c': 1, 'nc': 8, 'duration': 11.905771999999999}}
# no_of_edges_acc {'5': {'c': 0, 'nc': 12, 'duration': 1.28686, 'ac': 0.0}, '3': {'c': 2, 'nc': 4, 'duration': 1.563466, 'ac': 0.3333333333333333}}
# no_of_nodes_acc {'4': {'c': 2, 'nc': 16, 'duration': 25.086878, 'ac': 0.1111111111111111}}
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 1
# nc 17
# total_minutes 0.5833333333333334
# +++
# direct_indirect {'DI': {'c': 0, 'nc': 6, 'duration': 1.668887}, 'mixed': {'c': 1, 'nc': 5, 'duration': 4.921336}, 'inDI': {'c': 0, 'nc': 6, 'duration': 3.259808}}
# Crossed_not_crossed {'no': {'c': 0, 'nc': 9, 'duration': 21.366909999999997}, 'True': {'c': 1, 'nc': 8, 'duration': 23.066017}}
# no_of_edges_acc {'5': {'c': 1, 'nc': 11, 'duration': 3.259808, 'ac': 0.08333333333333333}, '3': {'c': 0, 'nc': 6, 'duration': 2.157484, 'ac': 0.0}}
# no_of_nodes_acc {'4': {'c': 1, 'nc': 17, 'duration': 44.432927, 'ac': 0.05555555555555555}}
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-5-mini'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 17
# nc 1
# total_minutes 6.816666666666666
# +++
# direct_indirect {'DI': {'c': 6, 'nc': 0, 'duration': 134.126091}, 'mixed': {'c': 5, 'nc': 1, 'duration': 117.792395}, 'inDI': {'c': 6, 'nc': 0, 'duration': 164.657927}}
# Crossed_not_crossed {'no': {'c': 8, 'nc': 1, 'duration': 189.59018899999998}, 'True': {'c': 9, 'nc': 0, 'duration': 226.986224}}
# no_of_edges_acc {'5': {'c': 11, 'nc': 1, 'duration': 279.434708, 'ac': 0.9166666666666666}, '3': {'c': 6, 'nc': 0, 'duration': 116.50872900000002, 'ac': 1.0}}
# no_of_nodes_acc {'4': {'c': 17, 'nc': 1, 'duration': 416.576413, 'ac': 0.9444444444444444}}
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-5-nano'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 18
# nc 0
# total_minutes 7.233333333333333
# +++
# direct_indirect {'DI': {'c': 6, 'nc': 0, 'duration': 136.50935299999998}, 'mixed': {'c': 6, 'nc': 0, 'duration': 153.896567}, 'inDI': {'c': 6, 'nc': 0, 'duration': 153.40371}}
# Crossed_not_crossed {'no': {'c': 9, 'nc': 0, 'duration': 205.93716199999997}, 'True': {'c': 9, 'nc': 0, 'duration': 237.872468}}
# no_of_edges_acc {'5': {'c': 12, 'nc': 0, 'duration': 292.65279899999996, 'ac': 1.0}, '3': {'c': 6, 'nc': 0, 'duration': 151.156831, 'ac': 1.0}}
# no_of_nodes_acc {'4': {'c': 18, 'nc': 0, 'duration': 443.80962999999997, 'ac': 1.0}}
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-5.2'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c
}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 5
# nc 55
# total_minutes 0.4
# +++
# direct_indirect {'': {'c': 5, 'nc': 55, 'duration': 0.884202}}
# Crossed_not_crossed {'True': {'c': 5, 'nc': 55, 'duration': 57.428024000000015}}
# no_of_edges_acc {'3': {'c': 1, 'nc': 21, 'duration': 0.863598, 'ac': 0.045454545454545456}, '4': {'c': 2, 'nc': 16, 'duration': 1.090602, 'ac': 0.1111111111111111}, '5': {'c': 1, 'nc': 15, 'duration': 1.012373, 'ac': 0.0625}, '6': {'c': 1, 'nc': 2, 'duration': 0.920459, 'ac': 0.3333333333333333}, '8': {'c': 0, 'nc': 1, 'duration': 0.884202, 'ac': 0.0}}
# no_of_nodes_acc {'3': {'c': 0, 'nc': 6, 'duration': 6.014729, 'ac': 0.0}, '4': {'c': 5, 'nc': 45, 'duration': 47.59255000000002, 'ac': 0.1}, '5': {'c': 0, 'nc': 2, 'duration': 2.016084, 'ac': 0.0}, '6': {'c': 0, 'nc': 2, 'duration': 1.804661, 'ac': 0.0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-pro'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 60
# nc 0
# total_minutes 14.383333333333333
# +++
# direct_indirect {'': {'c': 60, 'nc': 0, 'duration': 893.6666610000003}}
# Crossed_not_crossed {'True': {'c': 60, 'nc': 0, 'duration': 893.6666610000003}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 301.30254199999996, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 252.96328400000004, 'ac': 1.0}, '5': {'c': 16, 'nc': 0, 'duration': 271.256839, 'ac': 1.0}, '6': {'c': 3, 'nc': 0, 'duration': 48.512119, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 19.631877, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 6, 'nc': 0, 'duration': 88.043656, 'ac': 1.0}, '4': {'c': 50, 'nc': 0, 'duration': 731.0954690000001, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 34.766382, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 39.761154, 'ac': 1.0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-flash'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 58
# nc 2
# total_minutes 7.966666666666667
# +++
# direct_indirect {'': {'c': 58, 'nc': 2, 'duration': 461.752625}}
# Crossed_not_crossed {'True': {'c': 58, 'nc': 2, 'duration': 506.8729210000001}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 144.51237299999997, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 122.732535, 'ac': 1.0}, '5': {'c': 14, 'nc': 2, 'duration': 174.08599400000003, 'ac': 0.875}, '6': {'c': 3, 'nc': 0, 'duration': 30.822749, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 16.908301, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 4, 'nc': 2, 'duration': 76.638173, 'ac': 0.6666666666666666}, '4': {'c': 50, 'nc': 0, 'duration': 382.2262820000001, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 18.36722, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 29.641246000000002, 'ac': 1.0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-3-pro-preview'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 60
# nc 0
# total_minutes 19.866666666666667
# +++
# direct_indirect {'': {'c': 60, 'nc': 0, 'duration': 1222.6636159999998}}
# Crossed_not_crossed {'True': {'c': 60, 'nc': 0, 'duration': 1222.6636159999998}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 369.354773, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 325.27807399999995, 'ac': 1.0}, '5': {'c': 16, 'nc': 0, 'duration': 416.440102, 'ac': 1.0}, '6': {'c': 3, 'nc': 0, 'duration': 73.12230199999999, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 38.468365, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 6, 'nc': 0, 'duration': 110.07228799999999, 'ac': 1.0}, '4': {'c': 50, 'nc': 0, 'duration': 994.372448, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 51.961039, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 66.257841, 'ac': 1.0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-3-flash-preview'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 60
# nc 0
# total_minutes 16.983333333333334
# +++
# direct_indirect {'': {'c': 60, 'nc': 0, 'duration': 1048.915218}}
# Crossed_not_crossed {'True': {'c': 60, 'nc': 0, 'duration': 1048.915218}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 307.203089, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 256.949897, 'ac': 1.0}, '5': {'c': 16, 'nc': 0, 'duration': 365.106874, 'ac': 1.0}, '6': {'c': 3, 'nc': 0, 'duration': 65.321853, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 54.333505, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 6, 'nc': 0, 'duration': 106.61130600000001, 'ac': 1.0}, '4': {'c': 50, 'nc': 0, 'duration': 818.1643240000001, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 46.181099, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 77.958489, 'ac': 1.0}}

# %%
#direct_indirect_all,Crossed_not_crossed_all,no_of_edges_acc_all,no_of_nodes_acc_all=\
#direct_indirect_all_s2,Crossed_not_crossed_all_s2,no_of_edges_acc_all_s2,no_of_nodes_acc_all_s2

# %%
import pandas as pd
data = {
  "Models": [t[0] for t in direct_indirect_all],
  "Type":  [t[1] for t in direct_indirect_all],
 "Accuracy":  [t[-2] for t in direct_indirect_all],
 "Avg Time/Question(s)": [t[-1] for t in direct_indirect_all],

}
#load data into a DataFrame object:
df_direct_indirect_all = pd.DataFrame(data)
df_direct_indirect_all.head()
# Out:
#          Models  Type  Accuracy  Avg Time/Question(s)
# 0  gpt-4.1-mini    DI  0.166667              0.191652
# 1  gpt-4.1-mini  inDI  0.010000              0.214477
# 2       gpt-4.1    DI  0.010000              0.278148
# 3       gpt-4.1  inDI  0.010000              0.543301
# 4    gpt-5-mini    DI  1.000000             22.354349

# %%
import pandas as pd
data = {
  "Models": [t[0] for t in Crossed_not_crossed_all],
  "Crossed": [t[1] for t in Crossed_not_crossed_all],
 "Accuracy": [t[-2] for t in Crossed_not_crossed_all],
"Avg Time/Question(s)":  [t[-1] for t in Crossed_not_crossed_all],

}
#load data into a DataFrame object:
df_Crossed_not_crossed_all = pd.DataFrame(data)
df_Crossed_not_crossed_all.head(100)
# Out:
#                     Models Crossed  Accuracy  Avg Time/Question(s)
# 0             gpt-4.1-mini   False  0.111111              1.464567
# 1             gpt-4.1-mini    True  0.111111              1.322864
# 2                  gpt-4.1   False  0.010000              2.374101
# 3                  gpt-4.1    True  0.111111              2.562891
# 4               gpt-5-mini   False  0.888889             21.065577
# 5               gpt-5-mini    True  1.000000             25.220692
# 6               gpt-5-nano   False  1.000000             22.881907
# 7               gpt-5-nano    True  1.000000             26.430274
# 8                  gpt-5.2   False  0.222222              1.551985
# 9                  gpt-5.2    True  0.111111              1.363795
# 10        gemini-2.0-flash   False  0.111111              1.066635
# 11        gemini-2.0-flash    True  0.222222              1.025993
# 12          gemini-2.5-pro   False  1.000000             15.068661
# 13          gemini-2.5-pro    True  1.000000             18.114321
# 14        gemini-2.5-flash   False  1.000000              9.489065
# 15        gemini-2.5-flash    True  1.000000              9.707145
# 16    gemini-3-pro-preview   False  1.000000             17.054902
# 17    gemini-3-pro-preview    True  1.000000             21.372015
# 18  gemini-3-flash-preview   False  1.000000             18.764446
# 19  gemini-3-flash-preview    True  1.000000             13.964158

# %%
import pandas as pd
data = {
  "Models": [t[0] for t in no_of_edges_acc_all],
  "NO_Of_Edges": [t[1] for t in no_of_edges_acc_all],
 "Accuracy": [t[2] for t in no_of_edges_acc_all],
"Avg Time/Question(s)": [t[-1] for t in no_of_edges_acc_all],

}
#load data into a DataFrame object:
df_no_of_edges_acc_all = pd.DataFrame(data)

data = {
  "Models": [t[0] for t in no_of_edges_acc_all_s2],
  "No_Of_Edges": [t[1] for t in no_of_edges_acc_all_s2],
 "Accuracy": [t[2] for t in no_of_edges_acc_all_s2],
"Avg Time/Question(s)": [t[-1] for t in no_of_edges_acc_all_s2],

}
#load data into a DataFrame object:
df_no_of_edges_acc_all_ = pd.DataFrame(data)
df_no_of_edges_acc_all.head()
# Out:
#          Models NO_Of_Edges  Accuracy  Avg Time/Question(s)
# 0  gpt-4.1-mini           5  0.010000              0.107238
# 1  gpt-4.1-mini           3  0.333333              0.260578
# 2       gpt-4.1           5  0.083333              0.271651
# 3       gpt-4.1           3  0.010000              0.359581
# 4    gpt-5-mini           5  0.916667             23.286226

# %%
import pandas as pd
data = {
  "Models": [t[0] for t in no_of_nodes_acc_all],
  "No_Of_Nodes": [t[1] for t in no_of_nodes_acc_all],
 "Accuracy": [t[-2] for t in no_of_nodes_acc_all],
"Avg Time/Question(s)": [t[-1] for t in no_of_nodes_acc_all],

}
#load data into a DataFrame object:
df_no_of_nodes_acc_all = pd.DataFrame(data)
##
data = {
  "Models": [t[0] for t in no_of_nodes_acc_all_s2],
  "No_Of_Nodes":[t[1] for t in no_of_nodes_acc_all_s2],
 "Accuracy": [t[-2] for t in no_of_nodes_acc_all_s2],
"Avg Time/Question(s)": [t[-1] for t in no_of_nodes_acc_all_s2],

}
#load data into a DataFrame object:
df_no_of_nodes_acc_all_ = pd.DataFrame(data)

# %%
import plotly.express as px

df = px.data.gapminder()
df_2007 = df.query("year==2007")
["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]
template='ggplot2'

# %%
import pandas as pd
data_ = {
  "Models":[t[0] for t in direct_indirect_all],
  "Type":  [t[1] for t in direct_indirect_all],
 "Accuracy":  [t[-2] for t in direct_indirect_all],
 "Avg Time/Question(s)":  [t[-1] for t in direct_indirect_all],

}
#load data into a DataFrame object:
df_direct_indirect_all_duration = pd.DataFrame(data_)
df_direct_indirect_all_duration=df_direct_indirect_all_duration.groupby(['Models'])['Avg Time/Question(s)'].mean().reset_index()   
df_direct_indirect_all_duration.head()
# Out:
#                    Models  Avg Time/Question(s)
# 0        gemini-2.0-flash              0.333023
# 1        gemini-2.5-flash              8.806686
# 2          gemini-2.5-pro             16.200973
# 3  gemini-3-flash-preview             15.055425
# 4    gemini-3-pro-preview             18.690371

# %%
import plotly.express as px
template='ggplot2'
df = df_direct_indirect_all_duration.sort_values("Avg Time/Question(s)")
fig = px.bar(df, x="Models", y="Avg Time/Question(s)",
              barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/duration.png")

# %%
import plotly.express as px
template='ggplot2'
df = df_direct_indirect_all
fig = px.bar(df, x="Models", y="Avg Time/Question(s)",
             color='Type', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/duration_di_indi.png")

# %%
import plotly.express as px
template='ggplot2'
df = df_direct_indirect_all
fig = px.bar(df, x="Models", y="Accuracy",
             color='Type', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/di_indi.png")

# %%
import plotly.express as px
df = df_Crossed_not_crossed_all
fig = px.bar(df, x="Models", y="Accuracy",
             color='Crossed', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/crossed.png")

# %%
import plotly.express as px
template='ggplot2'
df = df_Crossed_not_crossed_all
fig = px.bar(df, x="Models", y="Avg Time/Question(s)",
             color='Crossed', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/duration_crossed.png")

# %%
import plotly.express as px
df = df_no_of_nodes_acc_all_
fig = px.bar(df, x="Models", y="Accuracy",
             color='No_Of_Nodes', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/acc_no_of_nodes.png")

# %%
import plotly.express as px
template='ggplot2'
df = df_no_of_nodes_acc_all_
fig = px.bar(df, x="Models", y="Avg Time/Question(s)",
             color='No_Of_Nodes', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/duration_no_of_nodes.png")

# %%
import plotly.express as px
df = df_no_of_edges_acc_all_
fig = px.bar(df, x="Models", y="Accuracy",
             color='No_Of_Edges', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/acc_no_of_edges.png")

# %%
import plotly.express as px
template='ggplot2'
df = df_no_of_edges_acc_all_
fig = px.bar(df, x="Models", y="Avg Time/Question(s)",
             color='No_Of_Edges', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/duration_no_of_edges.png")

# %%
import json

direct_indirect_all,Crossed_not_crossed_all,no_of_edges_acc_all,no_of_nodes_acc_all=eval_answer()
direct_indirect_all_s3,Crossed_not_crossed_all_s3,no_of_edges_acc_all_s3,no_of_nodes_acc_all_s3=eval_answer(flag=True)
# Out:
# questions_records[k] dict_keys(['original', 'v2'])
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1-mini'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 2
# nc 16
# total_minutes 0.31666666666666665
# +++
# direct_indirect {'DI': {'c': 1, 'nc': 5, 'duration': 1.149911}, 'mixed': {'c': 1, 'nc': 5, 'duration': 1.274292}, 'inDI': {'c': 0, 'nc': 6, 'duration': 1.28686}}
# Crossed_not_crossed {'no': {'c': 1, 'nc': 8, 'duration': 13.181106}, 'True': {'c': 1, 'nc': 8, 'duration': 11.905771999999999}}
# no_of_edges_acc {'5': {'c': 0, 'nc': 12, 'duration': 1.28686, 'ac': 0.0}, '3': {'c': 2, 'nc': 4, 'duration': 1.563466, 'ac': 0.3333333333333333}}
# no_of_nodes_acc {'4': {'c': 2, 'nc': 16, 'duration': 25.086878, 'ac': 0.1111111111111111}}
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c
0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-pro'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 60
# nc 0
# total_minutes 14.383333333333333
# +++
# direct_indirect {'': {'c': 60, 'nc': 0, 'duration': 893.6666610000003}}
# Crossed_not_crossed {'True': {'c': 60, 'nc': 0, 'duration': 893.6666610000003}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 301.30254199999996, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 252.96328400000004, 'ac': 1.0}, '5': {'c': 16, 'nc': 0, 'duration': 271.256839, 'ac': 1.0}, '6': {'c': 3, 'nc': 0, 'duration': 48.512119, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 19.631877, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 6, 'nc': 0, 'duration': 88.043656, 'ac': 1.0}, '4': {'c': 50, 'nc': 0, 'duration': 731.0954690000001, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 34.766382, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 39.761154, 'ac': 1.0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-flash'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 58
# nc 2
# total_minutes 7.966666666666667
# +++
# direct_indirect {'': {'c': 58, 'nc': 2, 'duration': 461.752625}}
# Crossed_not_crossed {'True': {'c': 58, 'nc': 2, 'duration': 506.8729210000001}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 144.51237299999997, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 122.732535, 'ac': 1.0}, '5': {'c': 14, 'nc': 2, 'duration': 174.08599400000003, 'ac': 0.875}, '6': {'c': 3, 'nc': 0, 'duration': 30.822749, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 16.908301, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 4, 'nc': 2, 'duration': 76.638173, 'ac': 0.6666666666666666}, '4': {'c': 50, 'nc': 0, 'duration': 382.2262820000001, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 18.36722, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 29.641246000000002, 'ac': 1.0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-3-pro-preview'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 60
# nc 0
# total_minutes 19.866666666666667
# +++
# direct_indirect {'': {'c': 60, 'nc': 0, 'duration': 1222.6636159999998}}
# Crossed_not_crossed {'True': {'c': 60, 'nc': 0, 'duration': 1222.6636159999998}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 369.354773, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 325.27807399999995, 'ac': 1.0}, '5': {'c': 16, 'nc': 0, 'duration': 416.440102, 'ac': 1.0}, '6': {'c': 3, 'nc': 0, 'duration': 73.12230199999999, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 38.468365, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 6, 'nc': 0, 'duration': 110.07228799999999, 'ac': 1.0}, '4': {'c': 50, 'nc': 0, 'duration': 994.372448, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 51.961039, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 66.257841, 'ac': 1.0}}
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-3-flash-preview'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# c 60
# nc 0
# total_minutes 16.983333333333334
# +++
# direct_indirect {'': {'c': 60, 'nc': 0, 'duration': 1048.915218}}
# Crossed_not_crossed {'True': {'c': 60, 'nc': 0, 'duration': 1048.915218}}
# no_of_edges_acc {'3': {'c': 22, 'nc': 0, 'duration': 307.203089, 'ac': 1.0}, '4': {'c': 18, 'nc': 0, 'duration': 256.949897, 'ac': 1.0}, '5': {'c': 16, 'nc': 0, 'duration': 365.106874, 'ac': 1.0}, '6': {'c': 3, 'nc': 0, 'duration': 65.321853, 'ac': 1.0}, '8': {'c': 1, 'nc': 0, 'duration': 54.333505, 'ac': 1.0}}
# no_of_nodes_acc {'3': {'c': 6, 'nc': 0, 'duration': 106.61130600000001, 'ac': 1.0}, '4': {'c': 50, 'nc': 0, 'duration': 818.1643240000001, 'ac': 1.0}, '5': {'c': 2, 'nc': 0, 'duration': 46.181099, 'ac': 1.0}, '6': {'c': 2, 'nc': 0, 'duration': 77.958489, 'ac': 1.0}}

# %%
import pandas as pd
data_s1 = {
  "Models": [t[0] for t in direct_indirect_all],
  "Session":  ['SesssionONe' for t in direct_indirect_all],
 "Accuracy":  [t[-2] for t in direct_indirect_all],
 "Avg Time/Question(s)": [t[-1] for t in direct_indirect_all],

}
data_s3 = {
  "Models": [t[0] for t in direct_indirect_all_s3],
  "Session":  ['SesssionONe' for t in direct_indirect_all_s3],
 "Accuracy":  [t[-2] for t in direct_indirect_all_s3],
 "Avg Time/Question(s)": [t[-1] for t in direct_indirect_all_s3],

}

data_s1 = pd.DataFrame(data_s1)
data_s1=data_s1.groupby(['Models'])['Accuracy'].mean().reset_index() 
##


#load data into a DataFrame object:
data_s3 = pd.DataFrame(data_s3)
data_s3=data_s3.groupby(['Models'])['Accuracy'].mean().reset_index() 
print(data_s3.shape[0])

data_s1 = data_s1.assign(session = ['s1' for t in range(data_s1.shape[0])])
data_s3 = data_s3.assign(session = ['s2' for t in range(data_s3.shape[0])])
#data_s3['session']=['s2' for t in range(data_s3.shape[0])]
#data_s1['session']=['s1' for t in range(data_s1.shape[0])]

data_s1.head()
data_new = pd.concat([data_s1, data_s3])
#data_new = pd.DataFrame(data_new)
data_new.head(100)
# Out:
# 10
#                    Models  Accuracy session
# 0        gemini-2.0-flash  0.171667      s1
# 1        gemini-2.5-flash  1.000000      s1
# 2          gemini-2.5-pro  1.000000      s1
# 3  gemini-3-flash-preview  1.000000      s1
# 4    gemini-3-pro-preview  1.000000      s1
# 5                 gpt-4.1  0.010000      s1
# 6            gpt-4.1-mini  0.088333      s1
# 7              gpt-5-mini  1.000000      s1
# 8              gpt-5-nano  1.000000      s1
# 9                 gpt-5.2  0.255000      s1
# 0        gemini-2.0-flash  0.083333      s2
# 1        gemini-2.5-flash  0.966667      s2
# 2          gemini-2.5-pro  1.000000      s2
# 3  gemini-3-flash-preview  1.000000      s2
# 4    gemini-3-pro-preview  1.000000      s2
# 5                 gpt-4.1  0.116667      s2
# 6            gpt-4.1-mini  0.133333      s2
# 7              gpt-5-mini  1.000000      s2
# 8              gpt-5-nano  0.933333      s2
# 9                 gpt-5.2  0.233333      s2

# %%
import plotly.express as px
template='ggplot2'
df = data_new

fig = px.bar(df, x="Models", y="Accuracy",
             color='session', barmode='group',template=template,text_auto=False,
             height=300)
fig.show()
fig.write_image("images/Session.png")

# %%
import pandas as pd
data_s1 = {
  "Models": [t[0] for t in direct_indirect_all],
  "Session":  ['SesssionONe' for t in direct_indirect_all],
 "Accuracy":  [t[-2] for t in direct_indirect_all],
 "Avg Time/Question(s)": [t[-1] for t in direct_indirect_all],

}
data_s3 = {
  "Models": [t[0] for t in direct_indirect_all_s3],
  "Session":  ['SesssionONe' for t in direct_indirect_all_s3],
 "Accuracy":  [t[-2] for t in direct_indirect_all_s3],
 "Avg Time/Question(s)": [t[-1] for t in direct_indirect_all_s3],

}

data_s1 = pd.DataFrame(data_s1)
data_s1=data_s1.groupby(['Models'])['Avg Time/Question(s)'].mean().reset_index() 
##


#load data into a DataFrame object:
data_s3 = pd.DataFrame(data_s3)
data_s3=data_s3.groupby(['Models'])['Avg Time/Question(s)'].mean().reset_index() 
print(data_s3.shape[0])

data_s1 = data_s1.assign(session = ['s1' for t in range(data_s1.shape[0])])
data_s3 = data_s3.assign(session = ['s2' for t in range(data_s3.shape[0])])
#data_s3['session']=['s2' for t in range(data_s3.shape[0])]
#data_s1['session']=['s1' for t in range(data_s1.shape[0])]

data_s1.head()
data_new = pd.concat([data_s1, data_s3])
#data_new = pd.DataFrame(data_new)
# Out:
# 10

# %%
import plotly.express as px
template='ggplot2'
df = data_new

fig = px.bar(df, x="Models", y="Avg Time/Question(s)",
             color='session', barmode='group',template=template,text_auto=False,
             height=300)
fig.show()
fig.write_image("images/Session_duration.png")
