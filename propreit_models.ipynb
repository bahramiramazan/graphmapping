# %%
import json

from Eval import eval_answer

# %%
data_experiment=eval_answer()
data_60_examples=eval_answer(flag=True)
# Out:
# questions_records[k] dict_keys(['original', 'v2'])
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1-mini'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-5-mini'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-5-nano'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gpt', 'model': 'gpt-5.2'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gemini', 'model': 'gemini-2.0-flash'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-pro'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-flash'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gemini', 'model': 'gemini-3-pro-preview'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name experiment
# selected_model {'agent': 'gemini', 'model': 'gemini-3-flash-preview'}
# Show_train_set False
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges no
# Crossed_edges no
# Crossed_edges no
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# questions_records[k] dict_keys(['original', 'v2'])
# ##############################
# data_name 60
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1-mini'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gpt', 'model': 'gpt-4.1'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gpt', 'model': 'gpt-5-mini'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gpt', 'model': 'gpt-5-nano'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gpt', 'model': 'gpt-5.2'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-2.0-flash'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-pro'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-2.5-flash'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-3-pro-preview'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# ##############################
# data_name 60
# selected_model {'agent': 'gemini', 'model': 'gemini-3-flash-preview'}
# Show_train_set False
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True
# Crossed_edges True

# %%
import pandas as pd
Data_experiment = pd.DataFrame(data_experiment)
Data_experiment.head()
# Out:
#    correctness  duration  type_ Crossed_edges no_of_edges no_of_nodes  \
# 0            0  1.318080     DI            no           5           4
# 1            0  1.288460  mixed            no           5           4
# 2            0  1.502063   inDI            no           5           4
# 3            0  1.053756     DI          True           5           4
# 4            0  1.274135  mixed          True           5           4
#
#           model
# 0  gpt-4.1-mini
# 1  gpt-4.1-mini
# 2  gpt-4.1-mini
# 3  gpt-4.1-mini
# 4  gpt-4.1-mini

# %%
overall = Data_experiment.groupby('model')['correctness'].mean().reset_index()   
overall.head(100)
# Out:
#                     model  correctness
# 0        gemini-2.0-flash     0.166667
# 1        gemini-2.5-flash     1.000000
# 2          gemini-2.5-pro     1.000000
# 3  gemini-3-flash-preview     1.000000
# 4    gemini-3-pro-preview     1.000000
# 5                 gpt-4.1     0.055556
# 6            gpt-4.1-mini     0.111111
# 7              gpt-5-mini     0.944444
# 8              gpt-5-nano     1.000000
# 9                 gpt-5.2     0.166667

# %%
overall = Data_experiment.groupby(['model','type_'])['correctness'].mean().reset_index()   
overall.head()
# Out:
#               model  type_  correctness
# 0  gemini-2.0-flash     DI     0.333333
# 1  gemini-2.0-flash   inDI     0.000000
# 2  gemini-2.0-flash  mixed     0.166667
# 3  gemini-2.5-flash     DI     1.000000
# 4  gemini-2.5-flash   inDI     1.000000

# %%
overall = Data_experiment.groupby(['model','Crossed_edges'])['correctness'].mean().reset_index()   
overall.head()

import plotly.express as px
template='ggplot2'
df = overall
fig = px.bar(df, x="model", y="correctness",
             color='Crossed_edges', barmode='group',template=template,text_auto=True,
             height=300)
fig.show()
fig.write_image("images/duration_di_indi.png")

# %%
import pandas as pd
Data_60 = pd.DataFrame(data_60_examples)
Data_60.head()
# Out:
#    correctness  duration type_ Crossed_edges no_of_edges no_of_nodes  \
# 0            0  2.098843                True           3           3
# 1            1  2.009309                True           3           3
# 2            0  2.546414                True           4           3
# 3            0  1.744250                True           4           3
# 4            0  2.086734                True           5           3
#
#           model
# 0  gpt-4.1-mini
# 1  gpt-4.1-mini
# 2  gpt-4.1-mini
# 3  gpt-4.1-mini
# 4  gpt-4.1-mini

# %%
overall = Data_60.groupby(['model','no_of_edges'])['correctness'].mean().reset_index()   
overall.head()

import plotly.express as px
template='ggplot2'
df = overall
fig = px.bar(df, x="model", y="correctness",
             color='no_of_edges', barmode='group',template=template,text_auto=True,
             height=500)
fig.show()
fig.write_image("images/duration_di_indi.png")
